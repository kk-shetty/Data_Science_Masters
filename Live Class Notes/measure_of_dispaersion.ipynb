# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Variance

# %%
students_marks = np.random.randint(28,98, 124)
sns.displot(data=students_marks, kde=True)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
np.var(students_marks)
# Out:
# 390.0548257023933

# %%
np.std(students_marks)
# Out:
# 19.74980571302901

# %%
np.mean(students_marks)
# Out:
# 63.45967741935484
