# %%
import pandas as pd

# %%
df = pd.read_csv("dumps/detailed_result_cleansed.csv")
df
# Out:
#            District  Constituency No.  Constituency Name  \
# 0          Belagavi                 1            Nippani
# 1          Belagavi                 2   Chikkodi-Sadalga
# 2          Belagavi                 3             Athani
# 3          Belagavi                 4             Kagwad
# 4          Belagavi                 5       Kudachi (SC)
# ..              ...               ...                ...
# 219          Mysore               220  T. Narasipur (SC)
# 220  Chamarajanagar               221              Hanur
# 221  Chamarajanagar               222      Kollegal (SC)
# 222  Chamarajanagar               223     Chamarajanagar
# 223  Chamarajanagar               224          Gundlupet
#
#          Winner Candidate Winner Party  Winner Votes  Winner %  \
# 0        Shashikala Jolle          BJP       73348.0     39.14
# 1          Ganesh Hukkeri          INC      128349.0     69.82
# 2           Laxman Savadi          INC      131404.0     68.34
# ...

# %%
df.dtypes
# Out:
# District                object
# Constituency No.         int64
# Constituency Name       object
# Winner Candidate        object
# Winner Party            object
# Winner Votes           float64
# Winner %               float64
# Runner Up Candidate     object
# Runner Up Party         object
# Runner Up Votes          int64
# Runner Up %            float64
# Margin                   int64
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#        Constituency No.   Winner Votes    Winner %  Runner Up Votes  \
# count        224.000000     224.000000  224.000000       224.000000
# mean         112.500000   86177.926174   49.559464     65535.334821
# std           64.807407   21869.826428    7.517976     17701.285185
# min            1.000000      95.463000   29.400000     20631.000000
# 25%           56.750000   73311.000000   45.110000     54130.750000
# 50%          112.500000   84412.500000   49.585000     64380.000000
# 75%          168.250000   94654.000000   53.837500     74074.750000
# max          224.000000  196220.000000   74.580000    154031.000000
#
#        Runner Up %         Margin
# count   224.000000     224.000000
# mean     37.547098   20979.535714
# std       6.964289   17872.183975
# min      11.080000      16.000000
# 25%      32.312500    7842.500000
# 50%      38.415000   15968.500000
# 75%      43.607500   30774.500000
# max      47.850000  122392.000000

# %%
df.dtypes
# Out:
# District                object
# Constituency No.         int64
# Constituency Name       object
# Winner Candidate        object
# Winner Party            object
# Winner Votes           float64
# Winner %               float64
# Runner Up Candidate     object
# Runner Up Party         object
# Runner Up Votes          int64
# Runner Up %            float64
# Margin                   int64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# District                True
# Constituency No.       False
# Constituency Name       True
# Winner Candidate        True
# Winner Party            True
# Winner Votes           False
# Winner %               False
# Runner Up Candidate     True
# Runner Up Party         True
# Runner Up Votes        False
# Runner Up %            False
# Margin                 False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# District               object
# Constituency Name      object
# Winner Candidate       object
# Winner Party           object
# Runner Up Candidate    object
# Runner Up Party        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['District', 'Constituency Name', 'Winner Candidate', 'Winner Party',
#        'Runner Up Candidate', 'Runner Up Party'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#            District  Constituency Name      Winner Candidate Winner Party  \
# 0          Belagavi            Nippani      Shashikala Jolle          BJP
# 1          Belagavi   Chikkodi-Sadalga        Ganesh Hukkeri          INC
# 2          Belagavi             Athani         Laxman Savadi          INC
# 3          Belagavi             Kagwad             Raju Kage          INC
# 4          Belagavi       Kudachi (SC)  Mahendra Tammannavar          INC
# ..              ...                ...                   ...          ...
# 219          Mysore  T. Narasipur (SC)     H. C. Mahadevappa          INC
# 220  Chamarajanagar              Hanur       M. R. Manjunath        JD(S)
# 221  Chamarajanagar      Kollegal (SC)   A. R. Krishnamurthy          INC
# 222  Chamarajanagar     Chamarajanagar   C. Puttarangashetty          INC
# 223  Chamarajanagar          Gundlupet   H. M. Ganesh Prasad          INC
#
#       Runner Up Candidate Runner Up Party
# ...

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                District Constituency Name Winner Candidate Winner Party  \
# count               224               224              224          224
# unique               31               224              223            6
# top     Bangalore Urban           Nippani    M. Krishnappa          INC
# freq                 28                 1                2          135
#
#        Runner Up Candidate Runner Up Party
# count                  224             224
# unique                 223               7
# top             V. Somanna             BJP
# freq                     2             111

# %%
df[df['District'] == 'Udupi']
# Out:
#     District  Constituency No. Constituency Name     Winner Candidate  \
# 117    Udupi               118           Byndoor    Gururaj Gantihole
# 118    Udupi               119         Kundapura    Kiran Kumar Kodgi
# 119    Udupi               120             Udupi   Yashpal A. Suvarna
# 120    Udupi               121              Kapu  Gurme Suresh Shetty
# 121    Udupi               122           Karkala       V. Sunil Kumar
#
#     Winner Party  Winner Votes  Winner %     Runner Up Candidate  \
# 117          BJP       98628.0     53.12        K Gopala Poojary
# 118          BJP      102424.0     61.16  Dinesh Hegde Molahalli
# 119          BJP       97079.0     58.46       Prasadraj Kanchan
# 120          BJP       80559.0     53.23      Vinay Kumar Sorake
# 121          BJP       77028.0     49.11    Udaya Shetty Muniyal
#
#     Runner Up Party  Runner Up Votes  Runner Up %  Margin
# 117             INC            82475        44.42   16153
# ...

# %%
df['Total Votes Polled'] = 0

# %%
df.head()
# Out:
#    District  Constituency No. Constituency Name      Winner Candidate  \
# 0  Belagavi                 1           Nippani      Shashikala Jolle
# 1  Belagavi                 2  Chikkodi-Sadalga        Ganesh Hukkeri
# 2  Belagavi                 3            Athani         Laxman Savadi
# 3  Belagavi                 4            Kagwad             Raju Kage
# 4  Belagavi                 5      Kudachi (SC)  Mahendra Tammannavar
#
#   Winner Party  Winner Votes  Winner %   Runner Up Candidate Runner Up Party  \
# 0          BJP       73348.0     39.14  Uttam Raosaheb Patil             NCP
# 1          INC      128349.0     69.82          Ramesh Katti             BJP
# 2          INC      131404.0     68.34     Mahesh Kumathalli             BJP
# 3          INC       83887.0     51.45        Shrimant Patil             BJP
# 4          INC       85321.0     56.87             P. Rajeev             BJP
#
#    Runner Up Votes  Runner Up %  Margin  Total Votes Polled
# ...

# %%
df['Winner Votes']
# Out:
# 0       73348.0
# 1      128349.0
# 2      131404.0
# 3       83887.0
# 4       85321.0
#          ...
# 219     77884.0
# 220     75632.0
# 221    108363.0
# 222     83858.0
# 223    107794.0
# Name: Winner Votes, Length: 224, dtype: float64

# %%
df['Winner %']
# Out:
# 0      39.14
# 1      69.82
# 2      68.34
# 3      51.45
# 4      56.87
#        ...
# 219    48.00
# 220    41.93
# 221    64.59
# 222    48.46
# 223    57.34
# Name: Winner %, Length: 224, dtype: float64

# %%
round((df['Winner Votes'] * 100) / (df['Winner %']))
# Out:
# 0      187399.0
# 1      183828.0
# 2      192280.0
# 3      163046.0
# 4      150028.0
#          ...
# 219    162258.0
# 220    180377.0
# 221    167771.0
# 222    173046.0
# 223    187991.0
# Length: 224, dtype: float64

# %%
df['Total Votes Polled'] = round((df['Winner Votes'] * 100) / (df['Winner %']))

# %%
df.head()
# Out:
#    District  Constituency No. Constituency Name      Winner Candidate  \
# 0  Belagavi                 1           Nippani      Shashikala Jolle
# 1  Belagavi                 2  Chikkodi-Sadalga        Ganesh Hukkeri
# 2  Belagavi                 3            Athani         Laxman Savadi
# 3  Belagavi                 4            Kagwad             Raju Kage
# 4  Belagavi                 5      Kudachi (SC)  Mahendra Tammannavar
#
#   Winner Party  Winner Votes  Winner %   Runner Up Candidate Runner Up Party  \
# 0          BJP       73348.0     39.14  Uttam Raosaheb Patil             NCP
# 1          INC      128349.0     69.82          Ramesh Katti             BJP
# 2          INC      131404.0     68.34     Mahesh Kumathalli             BJP
# 3          INC       83887.0     51.45        Shrimant Patil             BJP
# 4          INC       85321.0     56.87             P. Rajeev             BJP
#
#    Runner Up Votes  Runner Up %  Margin  Total Votes Polled
# ...

# %%
min(df['Winner Votes'])
# Out:
# 95.463

# %%
df['Winner Votes'] == min(df['Winner Votes'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# Name: Winner Votes, Length: 224, dtype: bool

# %%
df[df['Winner Votes'] == min(df['Winner Votes'])]
# Out:
#     District  Constituency No. Constituency Name         Winner Candidate  \
# 143    Kolar               144       Srinivaspur  G. K. Venkatashivareddy
#
#     Winner Party  Winner Votes  Winner % Runner Up Candidate Runner Up Party  \
# 143        JD(S)        95.463     49.99  K. R. Ramesh Kumar             INC
#
#      Runner Up Votes  Runner Up %  Margin  Total Votes Polled
# 143            85020        44.52   10443               191.0

# %%
df['Winner Votes'][143]
# Out:
# 95.463

# %%
float(str(df['Winner Votes'][143]).replace(".", ""))/10
# Out:
# 9546.3

# %%
df['Winner Votes'][143] = float(str(df['Winner Votes'][143]).replace(".", ""))/10
# Out:
# /tmp/ipykernel_917/4246630545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Winner Votes'][143] = float(str(df['Winner Votes'][143]).replace(".", ""))/10

# %%
df['Winner Votes'][143]
# Out:
# 9546.3

# %%
min(df['Winner Votes'])
# Out:
# 9546.3

# %%
df.describe()
# Out:
#        Constituency No.   Winner Votes    Winner %  Runner Up Votes  \
# count        224.000000     224.000000  224.000000       224.000000
# mean         112.500000   86220.117411   49.559464     65535.334821
# std           64.807407   21711.555127    7.517976     17701.285185
# min            1.000000    9546.300000   29.400000     20631.000000
# 25%           56.750000   73311.000000   45.110000     54130.750000
# 50%          112.500000   84412.500000   49.585000     64380.000000
# 75%          168.250000   94654.000000   53.837500     74074.750000
# max          224.000000  196220.000000   74.580000    154031.000000
#
#        Runner Up %         Margin  Total Votes Polled
# count   224.000000     224.000000          224.000000
# mean     37.547098   20979.535714       173691.236607
# std       6.964289   17872.183975        33164.168132
# min      11.080000      16.000000          191.000000
# 25%      32.312500    7842.500000       159406.250000
# ...

# %%
df['Winner Party'] == 'BJP'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# Name: Winner Party, Length: 224, dtype: bool

# %%
df['Margin'] < 1000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# Name: Margin, Length: 224, dtype: bool

# %%
df[(df['Winner Party'] == 'BJP') & (df['Margin'] < 1000)]
# Out:
#             District  Constituency No. Constituency Name  \
# 41        Kalaburagi                42    Chincholi (SC)
# 77    Uttara Kannada                78             Kumta
# 172  Bangalore Urban               173         Jayanagar
#
#           Winner Candidate Winner Party  Winner Votes  Winner %  \
# 41          Avinash Jadhav          BJP       69963.0     46.66
# 77   Dinakar Keshav Shetty          BJP       59965.0     40.37
# 172       C. K. Ramamurthy          BJP       57797.0     47.87
#
#     Runner Up Candidate Runner Up Party  Runner Up Votes  Runner Up %  Margin  \
# 41     Subash V. Rathod             INC            69105        46.09     858
# 77      Suraj Naik Soni           JD(S)            59289        39.92     676
# 172        Sowmya Reddy             INC            57781        47.85      16
#
#      Total Votes Polled
# 41             149942.0
# 77             148539.0
# 172            120737.0

# %%
df[(df['Runner Up Party'] == 'BJP') & (df['Margin'] < 1000)]
# Out:
#             District  Constituency No. Constituency Name  Winner Candidate  \
# 102       Davanagere               103      Jagalur (ST)    B. Devendrappa
# 122      Chikmagalur               123          Sringeri   T. D. Rajegowda
# 123      Chikmagalur               124     Mudigere (SC)    Nayana Motamma
# 148            Kolar               149             Malur  K. Y. Nanjegowda
# 163  Bangalore Urban               164      Gandhi Nagar  Dinesh Gundu Rao
#
#     Winner Party  Winner Votes  Winner %    Runner Up Candidate  \
# 102          INC       50765.0     32.44      S. V. Ramachandra
# 122          INC       59171.0     41.79         D. N. Jeevaraj
# 123          INC       50843.0     38.00        Deepak Doddaiah
# 148          INC       50955.0     29.40  K. S. Manjunathagowda
# 163          INC       54118.0     40.81  A.R. Sapthagiri Gowda
#
#     Runner Up Party  Runner Up Votes  Runner Up %  Margin  Total Votes Polled
# ...

# %%
df['Margin %'] = (df['Margin']/df['Total Votes Polled']) * 100

# %%
df[(df['Winner Party'] == 'BJP') & (df['Margin %'] < 1.0)]
# Out:
#             District  Constituency No. Constituency Name  \
# 41        Kalaburagi                42    Chincholi (SC)
# 47             Bidar                48          Humnabad
# 48             Bidar                49       Bidar South
# 77    Uttara Kannada                78             Kumta
# 87      Vijayanagara                88    Hadagalli (SC)
# 172  Bangalore Urban               173         Jayanagar
#
#           Winner Candidate Winner Party  Winner Votes  Winner %  \
# 41          Avinash Jadhav          BJP       69963.0     46.66
# 47             Siddu Patil          BJP       75515.0     42.23
# 48       Shailendra Bedale          BJP       49872.0     32.51
# 77   Dinakar Keshav Shetty          BJP       59965.0     40.37
# 87          Krishna Nayaka          BJP       73200.0     48.81
# 172       C. K. Ramamurthy          BJP       57797.0     47.87
#
#         Runner Up Candidate Runner Up Party  Runner Up Votes  Runner Up %  \
# ...

# %%
df[(df['Runner Up Party'] == 'BJP') & (df['Margin %'] < 1.0)]
# Out:
#             District  Constituency No. Constituency Name  Winner Candidate  \
# 102       Davanagere               103      Jagalur (ST)    B. Devendrappa
# 122      Chikmagalur               123          Sringeri   T. D. Rajegowda
# 123      Chikmagalur               124     Mudigere (SC)    Nayana Motamma
# 148            Kolar               149             Malur  K. Y. Nanjegowda
# 163  Bangalore Urban               164      Gandhi Nagar  Dinesh Gundu Rao
#
#     Winner Party  Winner Votes  Winner %    Runner Up Candidate  \
# 102          INC       50765.0     32.44      S. V. Ramachandra
# 122          INC       59171.0     41.79         D. N. Jeevaraj
# 123          INC       50843.0     38.00        Deepak Doddaiah
# 148          INC       50955.0     29.40  K. S. Manjunathagowda
# 163          INC       54118.0     40.81  A.R. Sapthagiri Gowda
#
#     Runner Up Party  Runner Up Votes  Runner Up %  Margin  Total Votes Polled  \
# ...

# %%
df.loc[0:10, ['District', 'Winner Party']]
# Out:
#     District Winner Party
# 0   Belagavi          BJP
# 1   Belagavi          INC
# 2   Belagavi          INC
# 3   Belagavi          INC
# 4   Belagavi          INC
# 5   Belagavi          BJP
# 6   Belagavi          BJP
# 7   Belagavi          BJP
# 8   Belagavi          BJP
# 9   Belagavi          INC
# 10  Belagavi          INC

# %%
df.iloc[0:10, [1,4,7]]
# Out:
#    Constituency No. Winner Party   Runner Up Candidate
# 0                 1          BJP  Uttam Raosaheb Patil
# 1                 2          INC          Ramesh Katti
# 2                 3          INC     Mahesh Kumathalli
# 3                 4          INC        Shrimant Patil
# 4                 5          INC             P. Rajeev
# 5                 6          BJP    Shambhu Kallolikar
# 6                 7          BJP           A. B. Patil
# 7                 8          BJP        Bhimappa Gadad
# 8                 9          BJP      Mahantesh Kadadi
# 9                10          INC      Basavaraj Hundri

# %%
data = {'name': ['John', 'Jane', 'Bob'], 'age': [25, 30, 35]}

df = pd.DataFrame(data)

print(df)

df_reindexed = df.reindex([2, 1, 0])

 

print(df_reindexed)
# Out:
#    name  age
# 0  John   25
# 1  Jane   30
# 2   Bob   35
#    name  age
# 2   Bob   35
# 1  Jane   30
# 0  John   25

# %%
data = {'name': ['John', 'Jane', 'Bob'], 'age': [25, 38, 35]}

df = pd.DataFrame(data)

 

for x in df.iterrows():
    # print(type(x))
    print(x)
    # print(index)
    # print(row)
    # print(row['name'], row['age'])

for x in df.itertuples():
    # print(type(x))
    print(x)
# Out:
# (0, name    John
# age       25
# Name: 0, dtype: object)
# (1, name    Jane
# age       30
# Name: 1, dtype: object)
# (2, name    Bob
# age      35
# Name: 2, dtype: object)
# Pandas(Index=0, name='John', age=25)
# Pandas(Index=1, name='Jane', age=30)
# Pandas(Index=2, name='Bob', age=35)

# %%
data = {'name': ['John', 'Jane', 'Bob', 'Rob', 'Jim'], 'age': [25, 38, 35, 24, 30]}

df = pd.DataFrame(data)
df.sort_values('age') # This will return a new df but won't change the existing DF
df
# Out:
#    name  age
# 0  John   25
# 1  Jane   38
# 2   Bob   35
# 3   Rob   24
# 4   Jim   30

# %%
type(df.loc[1:2, 'name'])
# Out:
# pandas.core.series.Series
